# %%
import pandas as pd

# %%
vuelos = pd.read_csv('vuelos.csv')
vuelos
# Out:
#         identificacionPasajero  ID vuelo asiento     clase  Precio_boleto  \
# 0                       178527       176     10F   Economy            NaN
# 1                        60548       134     36F   Economy     156.250305
# 2                       124289       336      9D   Premium     243.827387
# 3                       125115       429     15D   Economy     385.355754
# 4                        39485       518     17B   Economy     129.551739
# ...                        ...       ...     ...       ...            ...
# 133282                     378       717      8A   Economy     292.568470
# 133283                   48402        70     23E  Business      77.327654
# 133284                   67343       372     33C   Premium     107.389897
# 133285                  195358       212     42A  Business     300.507295
# 133286                   76837       737      1D   Economy     234.029325
#
#        fecha_compra genero        tipo_pago fecha_vuelo     aerolinea origin  \
# ...

# %%
vuelos.describe()
# Out:
#        identificacionPasajero       ID vuelo  Precio_boleto      dep_delay
# count           133287.000000  133287.000000  125866.000000  133287.000000
# mean             99798.342847     394.299909     265.839812       6.745534
# std              58068.246494     229.586668     209.378051      21.235182
# min                  1.000000       1.000000      18.139094     -53.000000
# 25%              48954.500000     198.000000     134.710783      -8.000000
# 50%              99215.000000     390.000000     247.651971       7.000000
# 75%             150274.500000     588.000000     346.959106      21.000000
# max             200000.000000     800.000000    4255.585606      70.000000
